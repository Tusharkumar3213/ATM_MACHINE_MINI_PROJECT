# %%
import time
print('\n---Please insite your Debit Card--- ')
time.sleep(1)

pin = int(input('\n--Please Inder Your 4 Digit ATM PIN---  '))
blance = 1500

if pin == 9090:
    while True:
        print('\n====WELCOME OUR ATM BANK MACHINE===\n')
        print('1 = Check Blance')
        print('2 = withdraw_money')
        print('3 = deposit_money')
        print('4 = Exit')
        
        try:
            option = int(input('\n Please choose any one option.=> '))
        except:
            print('Something went wrong,,. please try Againg.!!')
            
        if option == 1:
            print('--------------------')
            print(f'Your Current Blance is -->> {blance} \n')
            
        if option == 2:
            withdraw_money = int(input('Please Inter the withdrawal_amount..>'))
            blance = blance - withdraw_money
            print('--------------------------')
            print(f'{withdraw_money} Your debited blance is ...')
            print(f'Your Current Blance is -->> {blance} \n')
            
        if option == 3:
            deposit_amount = int(input('Please inter the deposit amount...>'))
            blance = blance + deposit_amount
            print('----------------------------')
            print(f'{deposit_amount} Your credited blance is ....')
            print(f'Your Current Blance is -->> {blance} \n')
            
        if option == 4:
            print('Thank you from visting our ATM BANK MACHINE ... Please come soon../')
            break
            
else:
    print('something went wrong.. Please try one more time.!!')
# Out:
# ---Please insite your Debit Card---
#
# --Please Inder Your 4 Digit ATM PIN---  9090
#
# ====WELCOME OUR ATM BANK MACHINE===
#
# 1 = Check Blance
# 2 = withdraw_money
# 3 = deposit_money
# 4 = Exit
#
#  Please choose any one option.=> 1
# --------------------
# Your Current Blance is -->> 1500
#
#
# ====WELCOME OUR ATM BANK MACHINE===
#
# 1 = Check Blance
# 2 = withdraw_money
# 3 = deposit_money
# 4 = Exit
#
#  Please choose any one option.=> 2
# Please Inter the withdrawal_amount..>100
# --------------------------
# 100 Your debited blance is ...
# Your Current Blance is -->> 1400
#
#
# ====WELCOME OUR ATM BANK MACHINE===
#
# 1 = Check Blance
# 2 = withdraw_money
# 3 = deposit_money
# 4 = Exit
#
#  Please choose any one option.=> 4
# Thank you from visting our ATM BANK MACHINE ... Please come soon../

# %%
import time 
print('WLCOME \n-----Please insite your atm card----\nPlease do not remove your card\n\tPlease wait few Second')
time.sleep(2)

pin = int(input('Please inter your 4 digit number---'))
blance = 1000

if pin == 9090:
    while True:
        print('\n===ATM MACHINE===\n')
        print('1 = check blance')
        print('2 = withdraw amount')
        print('3 = deposit money')
        print('4 = Exit the machine')
        
        try:
            option = int(input('\nPLEASE CHOOSE ANY ONE OPTION.-->> '))
        except:
            print('Sorry Something went wrong,, Please do one more time..')
            
        if option == 1:
            print('------------------------')
            print(f'Your Current Blance is,, {blance}')
            
        if option == 2:
            withdraw_money = int(input('please inter the withdrawal_amount..--> '))
            if withdraw_money <= blance:
                print('----------------------')
                blance = blance - withdraw_money
                print('\nplease wait your transaction is process')
                print('------------------------------------------|\n')
                time.sleep(3)
                print(f'{withdraw_money} Your amount has debited...|')
                print(f'Your Current Blance is,, {blance}')
                
        if option == 3:
            deposit_money = int(input('Please inter the deposit_amount..--> '))
            if deposit_money >= 1000:
                print('----------------------')
                blance = blance + deposit_money
                print(f'{deposit_money} Your amount has credited...| ')
                print(f'Your Current Blance is,, {blance}')
            else:
                print('Sorry you can not deposit ..')

        if option == 4:
            print('Thank you from visting our ATM BANK MACHINE ... Please come soon../')
            break
else:
    print('Oops something is wrong,, please try again.')
# Out:
# WLCOME
# -----Please insite your atm card----
# Please do not remove your card
# 	Please wait few Second
# Please inter your 4 digit number---9090
#
# ===ATM MACHINE===
#
# 1 = check blance
# 2 = withdraw amount
# 3 = deposit money
# 4 = Exit the machine
#
# PLEASE CHOOSE ANY ONE OPTION.-->> 1
# ------------------------
# Your Current Blance is,, 1000
#
# ===ATM MACHINE===
#
# 1 = check blance
# 2 = withdraw amount
# 3 = deposit money
# 4 = Exit the machine
#
# PLEASE CHOOSE ANY ONE OPTION.-->> 2
# please inter the withdrawal_amount..--> 500
# ----------------------
#
# please wait your transaction is process
# ------------------------------------------|
#
# 500 Your amount has debited...|
# Your Current Blance is,, 500
#
# ===ATM MACHINE===
#
# 1 = check blance
# 2 = withdraw amount
# 3 = deposit money
# 4 = Exit the machine
#
# PLEASE CHOOSE ANY ONE OPTION.-->> 1
# ------------------------
# Your Current Blance is,, 500
#
# ===ATM MACHINE===
#
# 1 = check blance
# 2 = withdraw amount
# 3 = deposit money
# 4 = Exit the machine
#
# PLEASE CHOOSE ANY ONE OPTION.-->> 3
# Please inter the deposit_amount..--> 100
# Sorry you can not deposit ..
#
# ===ATM MACHINE===
#
# 1 = check blance
# 2 = withdraw amount
# 3 = deposit money
# 4 = Exit the machine
#
# PLEASE CHOOSE ANY ONE OPTION.-->> 4
# Thank you from visting our ATM BANK MACHINE ... Please come soon../
